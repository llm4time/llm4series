# %%
import llm4series as ls

# %%
ts = ls.read_file("data/OT.csv", index_col="date")
ts
# Out:
# date
# 2016-07-01 00:00:00    38.661999
# 2016-07-01 01:00:00    37.124001
# 2016-07-01 02:00:00    36.465000
# 2016-07-01 03:00:00    33.608501
# 2016-07-01 04:00:00    31.850500
#                          ...
# 2018-06-26 15:00:00    47.084999
# 2018-06-26 16:00:00    48.183498
# 2018-06-26 17:00:00    48.183498
# 2018-06-26 18:00:00    46.865501
# 2018-06-26 19:00:00    45.986500
# Freq: h, Name: OT, Length: 17420, dtype: float64

# %%
ts.plot(kind='chart', title="OT", xlabel="Date", ylabel="Value")

# %%
ts[:100].plot(kind='line', title="OT", xlabel="Date", ylabel="Value")

# %%
ts.plot(kind='bar', title="OT", xlabel="Statistics", ylabel="Value")

# %%
ts.plot(kind='stl', title="OT", xlabel="Date", ylabel="Value")

# %%
ts.plot(kind='autocorr', title="OT", xlabel="Lag", ylabel="Value")
